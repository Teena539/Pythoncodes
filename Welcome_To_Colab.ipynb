# %% [markdown]
# <a href="https://colab.research.google.com/github/Teena539/Pythoncodes/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: Using dataframe data: generate code for descriptive statistics,nominal data,ordinal data,measures of data,variance,and standard deviation,range,skewness,outliers by using above dataset

import pandas as pd
import numpy as np

# Descriptive Statistics
print("Descriptive Statistics:")
print(data.describe())


# Measures of central tendency (mean, median, mode)
print("\nMeasures of Central Tendency:")
print("Mean:", data.mean())
print("Median:", data.median())

# Mode is not directly available for numeric columns, calculate for categorical/discrete ones if any
# For example, if "Membership_Years" were categorical, you could use:
# print("Mode (Membership Years):", data['Membership_Years'].mode())


# Measures of Dispersion
print("\nMeasures of Dispersion:")
print("Variance:", data.var())
print("Standard Deviation:", data.std())
print("Range:", data.max() - data.min())



# Skewness
print("\nSkewness:")
print(data.skew())

# Outlier Detection (using IQR method)
print("\nOutliers (IQR method):")
def detect_outliers_iqr(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = data[(data < lower_bound) | (data > upper_bound)]
    return outliers

for col in data.select_dtypes(include=np.number):
  print(f"\nOutliers in {col}:")
  print(detect_outliers_iqr(data[col]))


# Nominal and ordinal data handling
# If there were nominal or ordinal columns, you'd analyze them differently:

#Nominal data
print("\nNominal Data Analysis (Example - If there were categorical data)")
#For example if there was a column 'Gender'
#print(data["Gender"].value_counts())

#Ordinal data (Example)
#If there was a column named customer satisfaction which is ordinal
print("\nOrdinal Data Analysis (Example)")
#print(data["customer_satisfaction"].value_counts(normalize=True) * 100) #Get % of different satisfaction levels


# ... (Add other analyses as needed)
# Out:
# Descriptive Statistics:
#             Number          Age        Income  Spending_Score  \
# count  1362.000000  1362.000000   1362.000000     1362.000000
# mean    681.500000    43.251836  48317.193784     9765.372547
# std     393.319844    12.533236  12648.638324     2531.133100
# min       1.000000    18.000000  19946.675740     4064.177336
# 25%     341.250000    33.000000  38532.229703     7830.921337
# 50%     681.500000    43.000000  48758.233625     9850.200389
# 75%    1021.750000    54.000000  58579.901010    11810.345793
# max    1362.000000    64.000000  73182.569800    14791.611800
#
#        Membership_Years  Purchase_Frequency  Last_Purchase_Amount
# count       1362.000000         1362.000000           1362.000000
# mean           9.513950           49.551706           4931.689546
# std            5.417624           27.074169           1266.894447
# min            1.000000            4.876052           2057.551913
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
