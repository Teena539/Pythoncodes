# %% [markdown]
# <a href="https://colab.research.google.com/github/Teena539/Pythoncodes/blob/main/Day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ac386df3-f03c-4a1e-bea9-7510e069aa69" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ac386df3-f03c-4a1e-bea9-7510e069aa69">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls
# Out:
# sample_data  weather_prediction_dataset.csv

# %%
import pandas as pd
df = pd.read_csv('/content/weather_prediction_dataset.csv')

# %%
df
# Out:
#           DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0     20000101      1                8.0            0.89          1.0286
# 1     20000102      1                8.0            0.87             NaN
# 2     20000103      1                NaN            0.81          1.0314
# 3     20000104      1                7.0            0.79          1.0262
# 4     20000105      1                5.0            0.90          1.0246
# ...        ...    ...                ...             ...             ...
# 3649  20091228     12                7.0            0.82          1.0084
# 3650  20091229     12                7.0            0.92          1.0028
# 3651  20091230     12                8.0            0.92          0.9979
# 3652  20091231     12                7.0            0.93          0.9958
# 3653  20100101      1                8.0            0.93          0.9965
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# ...

# %%
df.isnull().any()
# Out:
# DATE                      False
# MONTH                     False
# BASEL_cloud_cover          True
# BASEL_humidity            False
# BASEL_pressure             True
#                           ...
# TOURS_global_radiation     True
# TOURS_precipitation        True
# TOURS_temp_mean           False
# TOURS_temp_min             True
# TOURS_temp_max            False
# Length: 165, dtype: bool

# %%
df.fillna(df.mean())
# Out:
#           DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0     20000101      1            8.00000            0.89        1.028600
# 1     20000102      1            8.00000            0.87        1.017872
# 2     20000103      1            5.41856            0.81        1.031400
# 3     20000104      1            7.00000            0.79        1.026200
# 4     20000105      1            5.00000            0.90        1.024600
# ...        ...    ...                ...             ...             ...
# 3649  20091228     12            7.00000            0.82        1.008400
# 3650  20091229     12            7.00000            0.92        1.002800
# 3651  20091230     12            8.00000            0.92        0.997900
# 3652  20091231     12            7.00000            0.93        0.995800
# 3653  20100101      1            8.00000            0.93        0.996500
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# ...

# %%
df.fillna(df.median())
# Out:
#           DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0     20000101      1                8.0            0.89          1.0286
# 1     20000102      1                8.0            0.87          1.0177
# 2     20000103      1                6.0            0.81          1.0314
# 3     20000104      1                7.0            0.79          1.0262
# 4     20000105      1                5.0            0.90          1.0246
# ...        ...    ...                ...             ...             ...
# 3649  20091228     12                7.0            0.82          1.0084
# 3650  20091229     12                7.0            0.92          1.0028
# 3651  20091230     12                8.0            0.92          0.9979
# 3652  20091231     12                7.0            0.93          0.9958
# 3653  20100101      1                8.0            0.93          0.9965
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# ...

# %%
df.fillna(df.mode().iloc[0])
# Out:
#           DATE  MONTH  BASEL_cloud_cover  BASEL_humidity  BASEL_pressure  \
# 0     20000101      1                8.0            0.89          1.0286
# 1     20000102      1                8.0            0.87          1.0179
# 2     20000103      1                7.0            0.81          1.0314
# 3     20000104      1                7.0            0.79          1.0262
# 4     20000105      1                5.0            0.90          1.0246
# ...        ...    ...                ...             ...             ...
# 3649  20091228     12                7.0            0.82          1.0084
# 3650  20091229     12                7.0            0.92          1.0028
# 3651  20091230     12                8.0            0.92          0.9979
# 3652  20091231     12                7.0            0.93          0.9958
# 3653  20100101      1                8.0            0.93          0.9965
#
#       BASEL_global_radiation  BASEL_precipitation  BASEL_sunshine  \
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame

# 1. Select numerical columns
numerical_cols = df.select_dtypes(include=['number']).columns

# 2. Melt the DataFrame to create a long-form dataset
melted_df = pd.melt(df, value_vars=numerical_cols, var_name='Feature', value_name='Value')

# 3. Create a single box plot for all features
plt.figure(figsize=(12, 8))  # Adjust figure size if needed
sns.boxplot(x='Feature', y='Value', data=melted_df)
plt.title('Box Plot of All Numerical Features')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame and 'column_name' is the name of the column you want to visualize
column_name = 'BASEL_cloud_cover'  # Replace with the actual column name

plt.figure(figsize=(8, 6))  # Adjust figure size as needed
sns.boxplot(x=df[column_name])
plt.title(f'Box Plot of {column_name}')
plt.show()

# %%
for column in numerical_cols:
    plt.figure(figsize=(8, 6))  # Adjust figure size as needed
    sns.boxplot(x=df[column])
    plt.title(f'Box Plot of {column}')
    plt.show()
